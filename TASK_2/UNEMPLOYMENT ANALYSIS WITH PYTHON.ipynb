# %% [markdown]
# # UNEMPLOYMENT ANALYSIS WITH PYTHON

# %%
from IPython.display import Image
img = 'Covid.JPG' 
Image(filename=img)

# %%
#Loading the necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mlp
import plotly.express as px
# %matplotlib inline

# %%
# Load the data set
df1 = pd.read_csv("Unemployment in India.csv")
df2 = pd.read_csv("Unemployment_Rate_upto_11_2020.csv")

# %% [markdown]
# ### Explorating Data Analysis

# %%
df1.head(2)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural

# %%
df2.head(2)
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
#
#    longitude  latitude
# 0    15.9129     79.74
# 1    15.9129     79.74

# %% [markdown]
# ### Analyze Data Summary

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 42.1+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %% [markdown]
# ### Statistic Summary of Dataset

# %%
df1.shape
# Out:
# (768, 7)

# %%
df2.shape
# Out:
# (267, 9)

# %%
df1.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        740.000000         7.400000e+02
# mean                          11.787946         7.204460e+06
# std                           10.721298         8.087988e+06
# min                            0.000000         4.942000e+04
# 25%                            4.657500         1.190404e+06
# 50%                            8.350000         4.744178e+06
# 75%                           15.887500         1.127549e+07
# max                           76.740000         4.577751e+07
#
#         Estimated Labour Participation Rate (%)
# count                                740.000000
# mean                                  42.630122
# std                                    8.111094
# min                                   13.330000
# 25%                                   38.062500
# 50%                                   41.160000
# 75%                                   45.505000
# ...

# %%
df2.describe()
# Out:
#         Estimated Unemployment Rate (%)   Estimated Employed  \
# count                        267.000000         2.670000e+02
# mean                          12.236929         1.396211e+07
# std                           10.803283         1.336632e+07
# min                            0.500000         1.175420e+05
# 25%                            4.845000         2.838930e+06
# 50%                            9.650000         9.732417e+06
# 75%                           16.755000         2.187869e+07
# max                           75.850000         5.943376e+07
#
#         Estimated Labour Participation Rate (%)   longitude    latitude
# count                                267.000000  267.000000  267.000000
# mean                                  41.681573   22.826048   80.532425
# std                                    7.845419    6.270731    5.831738
# min                                   16.770000   10.850500   71.192400
# ...

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Checking for Null values

# %%
df1.isnull()
# Out:
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0     False  False       False                             False
# 1     False  False       False                             False
# 2     False  False       False                             False
# 3     False  False       False                             False
# 4     False  False       False                             False
# ..      ...    ...         ...                               ...
# 763    True   True        True                              True
# 764    True   True        True                              True
# 765    True   True        True                              True
# 766    True   True        True                              True
# 767    True   True        True                              True
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0                  False                                     False  False
# ...

# %%
df2.isna()
# Out:
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0     False  False       False                             False
# 1     False  False       False                             False
# 2     False  False       False                             False
# 3     False  False       False                             False
# 4     False  False       False                             False
# ..      ...    ...         ...                               ...
# 262   False  False       False                             False
# 263   False  False       False                             False
# 264   False  False       False                             False
# 265   False  False       False                             False
# 266   False  False       False                             False
#
#       Estimated Employed   Estimated Labour Participation Rate (%)  Region.1  \
# 0                  False                                     False     False
# ...

# %% [markdown]
# ### Dropping Null Values

# %%
df1 = df1.dropna()
df1.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df2 = df2.dropna()
df2.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
#Check columns and rename them for better understanding
df1.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# ## Rename Column Name

# %%
df1.columns = ['State', 'Date', 'Frequency', 'Est_unemp', 'Est_emp', 'Est_Lab', 'Area']
df1.columns
# Out:
# Index(['State', 'Date', 'Frequency', 'Est_unemp', 'Est_emp', 'Est_Lab',
#        'Area'],
#       dtype='object')

# %%
df2.columns = ['State', 'Date', 'Frequency', 'Est_unemp', 'Est_emp', 'Est_Lab','Reg_1','longitude','latitude']
df2.columns
# Out:
# Index(['State', 'Date', 'Frequency', 'Est_unemp', 'Est_emp', 'Est_Lab',
#        'Reg_1', 'longitude', 'latitude'],
#       dtype='object')

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Unemployment Rate By Region in India

# %%
fig = px.box(df2, x='Reg_1', y='Est_unemp',color ="Reg_1",title="Unemployment Rate By Region in India")
fig.show()
# Out:
# <div>                            <div id="01ec6cea-4f6c-4884-9634-4d3f8071701d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("01ec6cea-4f6c-4884-9634-4d3f8071701d")) {                    Plotly.newPlot(                        "01ec6cea-4f6c-4884-9634-4d3f8071701d",                        [{"alignmentgroup":"True","hovertemplate":"Reg_1=%{x}<br>Est_unemp=%{y}<extra></extra>","legendgroup":"South","marker":{"color":"#636efa"},"name":"South","notched":false,"offsetgroup":"South","orientation":"v","showlegend":true,"x":["South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","South","So
# ...

# %% [markdown]
# #### The Figure describes that the Northern Part of India is highly unemployed

# %% [markdown]
# ### Unemployment Rate of States in India

# %%
fig = px.bar(df2, x='State', y='Est_unemp', color = 'State',
             title="Unemployment Rates State wise")
fig.show()
# Out:
# <div>                            <div id="8021163a-31e1-49e3-b71a-cf9d40ebe99a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8021163a-31e1-49e3-b71a-cf9d40ebe99a")) {                    Plotly.newPlot(                        "8021163a-31e1-49e3-b71a-cf9d40ebe99a",                        [{"alignmentgroup":"True","hovertemplate":"State=%{x}<br>Est_unemp=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh"],"xaxis":
# ...

# %% [markdown]
# #### The Graphs represents that HARYANA has the highest unemployment rate in India.

# %% [markdown]
# #### Labour Participation Rate

# %%
sns.scatterplot(data=df1, x='Est_emp', y='Est_Lab')
plt.title('Labour Participation Rate')
plt.xlabel('Estimated Employment rate')
plt.ylabel('Estimated Labour Participation rate')
# Out:
# Text(0, 0.5, 'Estimated Labour Participation rate')

# %% [markdown]
# #### Estimated Employment in Different Regions

# %%
plt.title("Indian Employment 2020")
sns.histplot(x="Est_emp", hue="Reg_1", data=df2)
plt.show()

# %% [markdown]
# #### Estimated Unemployment in Different States 2020

# %%
sns.barplot(data = df2, x='State', y='Est_unemp')
plt.title('Unemployment in Different Regions')
plt.xlabel('Region')
plt.ylabel('Estimated Unmemployment rate')
plt.xticks(rotation=90)
plt.figure(figsize=(50, 20))

# %%
plt.title("Indian Unemployment")
sns.histplot(x="Est_unemp", hue="Reg_1", data=df2)
plt.show()

# %% [markdown]
# ### The unemployment rate of each Indian State by region

# %%
unemploment = df2[["State", "Reg_1", "Est_unemp"]]
figure = px.sunburst(unemploment, path=["Reg_1", "State"],values="Est_unemp",width=700, height=700,
                     color_continuous_scale="RdY1Gn",title="Unemployment Rate in India")
figure.show()
# Out:
# <div>                            <div id="91f75f62-f7eb-42cf-a13a-f57b2e8b332c" class="plotly-graph-div" style="height:700px; width:700px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("91f75f62-f7eb-42cf-a13a-f57b2e8b332c")) {                    Plotly.newPlot(                        "91f75f62-f7eb-42cf-a13a-f57b2e8b332c",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Est_unemp=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["South/Andhra Pradesh","Northeast/Assam","East/Bihar","West/Chhattisgarh","North/Delhi","West/Goa","West/Gujarat","North/Haryana","North/Himachal Pradesh","North/Jammu & Kashmir","East/Jharkhand","South/Karnataka","South/Kerala","West/Madhya Pradesh","West/Maharashtra","Northeast/Meghalaya","
# ...

# %%
sns.pairplot(df2)
# Out:
# C:\Users\97152\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning:
#
# The figure layout has changed to tight

# %% [markdown]
# ## MODEL TRAINING

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# ### Metrics for Evaluating Models

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import  classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Defining The Feature Matrix

# %%
x = df2[['Est_unemp', 'Est_emp', 'Est_Lab','longitude', 'latitude']]

y = df2['Est_emp']
x_train, x_test, y_train, y_test = train_test_split(x, y)

# %% [markdown]
# ### MODEL TRAINING

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
import statsmodels.api as sm


lin_reg = LinearRegression()
lin_reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
coef_data = pd.DataFrame(lin_reg.coef_, x.columns, columns=['Coefficient'])
coef_data
# Out:
#             Coefficient
# Est_unemp -2.033993e-11
# Est_emp    1.000000e+00
# Est_Lab    8.437300e-12
# longitude -1.204970e-11
# latitude  -1.472189e-11

# %%
predictions = lin_reg.predict(x_test)

# %% [markdown]
# ### Plotting the prediction

# %%
plt.scatter(y_test, predictions)

# %%
sns.distplot((y_test,predictions),bins=50);
# Out:
# C:\Users\97152\AppData\Local\Temp\ipykernel_16644\1608389392.py:1: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751

# %% [markdown]
# # Summary Of the Report

# %% [markdown]
# 1) This data science project contributes to the ongoing discourse on unemployment by leveraging machine learning techniques for a nuanced analysis.
#
# 2) The combination of data-driven insights and predictive modeling equips stakeholders with a valuable tool for informed decision-making and proactive measures in addressing unemployment challenges.
#
# 3) The integration of machine learning methodologies in economic analysis holds promise for fostering a more resilient and adaptive approach to labor market challenges.
#
# In conclusion the analysis of Unemployment in India helped me to the understand the pandemic situation and find valuable insights to clearly understand the development of country.

# %% [markdown]
# # ___________________________________________________________
